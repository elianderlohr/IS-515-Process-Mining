# %%
import pm4py
import os

# %%
log = pm4py.read_xes(os.path.join("data", "BPI_Challenge_2019-3-w-after.xes.gz"))
# Out:
# parsing log, completed traces ::   0%|          | 0/15182 [00:00<?, ?it/s]

# %%
bpmn_graph = pm4py.read_bpmn("./bpmn/BPMN_Celonis_as-is_final.bpmn"
                             )

net, im, fm = pm4py.convert_to_petri_net(bpmn_graph)

# %% [markdown]
# # Token-based replay

# %%
pm4py.conformance_diagnostics_token_based_replay(log, net, im, fm)
# Out:
# replaying log with TBR, completed variants ::   0%|          | 0/4228 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 pm4py.conformance_diagnostics_token_based_replay(log, net, im, fm)
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\conformance.py:87, in conformance_diagnostics_token_based_replay(log, petri_net, initial_marking, final_marking)
#      84 if type(log) not in [pd.DataFrame, EventLog, EventStream]: raise Exception("the method can be applied only to a traditional event log!")
#      86 from pm4py.algo.conformance.tokenreplay import algorithm as token_replay
# ---> 87 return token_replay.apply(log, petri_net, initial_marking, final_marking, parameters=get_properties(log))
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\algo\conformance\tokenreplay\algorithm.py:60, in apply(log, net, initial_marking, final_marking, parameters, variant)
#      58 if parameters is None:
#      59     parameters = {}
# ---> 60 return exec_utils.get_variant(variant).apply(log_converter.apply(log, variant=log_converter.TO_EVENT_LOG, parameters=parameters), net, initial_marking,
#      61                          final_marking, parameters=parameters)
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\algo\conformance\tokenreplay\variants\token_replay.py:1151, in apply(log, net, initial_marking, final_marking, parameters)
#    1147 consider_activities_not_in_model_in_fitness = exec_utils.get_param_value(Parameters.CONSIDER_ACTIVITIES_NOT_IN_MODEL_IN_FITNESS, parameters, False)
#    1149 show_progress_bar = exec_utils.get_param_value(Parameters.SHOW_PROGRESS_BAR, parameters, True)
# -> 1151 return apply_log(log, net, initial_marking, final_marking, enable_pltr_fitness=enable_pltr_fitness,
#    1152                  consider_remaining_in_fitness=consider_remaining_in_fitness,
#    1153                  reach_mark_through_hidden=try_to_reach_final_marking_through_hidden,
#    1154                  stop_immediately_unfit=stop_immediately_unfit,
#    1155                  walk_through_hidden_trans=walk_through_hidden_trans,
#    1156                  places_shortest_path_by_hidden=places_shortest_path_by_hidden, activity_key=activity_key,
#    1157                  variants=variants, is_reduction=is_reduction, thread_maximum_ex_time=thread_maximum_ex_time,
#    1158                  cleaning_token_flood=cleaning_token_flood, disable_variants=disable_variants,
#    1159                  return_object_names=return_names, show_progress_bar=show_progress_bar,
#    1160                  consider_activities_not_in_model_in_fitness=consider_activities_not_in_model_in_fitness)
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\algo\conformance\tokenreplay\variants\token_replay.py:1053, in apply_log(log, net, initial_marking, final_marking, enable_pltr_fitness, consider_remaining_in_fitness, activity_key, reach_mark_through_hidden, stop_immediately_unfit, walk_through_hidden_trans, places_shortest_path_by_hidden, variants, is_reduction, thread_maximum_ex_time, cleaning_token_flood, disable_variants, return_object_names, show_progress_bar, consider_activities_not_in_model_in_fitness)
#    1035 variant = vc[i][0]
#    1036 threads[variant] = ApplyTraceTokenReplay(variants[variant][0], net, initial_marking, final_marking,
#    1037                                          trans_map, enable_pltr_fitness, place_fitness_per_trace,
#    1038                                          transition_fitness_per_trace,
#    (...)
#    1051                                          s_components=s_components, trace_occurrences=vc[i][1],
#    1052                                          consider_activities_not_in_model_in_fitness=consider_activities_not_in_model_in_fitness)
# -> 1053 threads[variant].run()
#    1054 if progress is not None:
#    1055     progress.update()
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\algo\conformance\tokenreplay\variants\token_replay.py:849, in ApplyTraceTokenReplay.run(self)
#     844 def run(self):
#     845     """
#     846     Runs the thread and stores the results
#     847     """
#     848     self.t_fit, self.t_value, self.act_trans, self.trans_probl, self.reached_marking, self.enabled_trans_in_mark, self.missing, self.consumed, self.remaining, self.produced = \
# --> 849         apply_trace(self.trace, self.net, self.initial_marking, self.final_marking, self.trans_map,
#     850                     self.enable_pltr_fitness, self.place_fitness, self.transition_fitness,
#     851                     self.notexisting_activities_in_model,
#     852                     self.places_shortest_path_by_hidden, self.consider_remaining_in_fitness,
#     853                     activity_key=self.activity_key,
#     854                     try_to_reach_final_marking_through_hidden=self.try_to_reach_final_marking_through_hidden,
#     855                     stop_immediately_unfit=self.stop_immediately_when_unfit,
#     856                     walk_through_hidden_trans=self.walk_through_hidden_trans,
#     857                     post_fix_caching=self.post_fix_caching,
#     858                     marking_to_activity_caching=self.marking_to_activity_caching,
#     859                     is_reduction=self.is_reduction,
#     860                     thread_maximum_ex_time=self.thread_maximum_ex_time,
#     861                     enable_postfix_cache=self.enable_postfix_cache,
#     862                     enable_marktoact_cache=self.enable_marktoact_cache,
#     863                     cleaning_token_flood=self.cleaning_token_flood,
#     864                     s_components=self.s_components,
#     865                     trace_occurrences=self.trace_occurrences,
#     866                     consider_activities_not_in_model_in_fitness=self.consider_activities_not_in_model_in_fitness)
#     867     self.thread_is_alive = False
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\algo\conformance\tokenreplay\variants\token_replay.py:743, in apply_trace(trace, net, initial_marking, final_marking, trans_map, enable_pltr_fitness, place_fitness, transition_fitness, notexisting_activities_in_model, places_shortest_path_by_hidden, consider_remaining_in_fitness, activity_key, try_to_reach_final_marking_through_hidden, stop_immediately_unfit, walk_through_hidden_trans, post_fix_caching, marking_to_activity_caching, is_reduction, thread_maximum_ex_time, enable_postfix_cache, enable_marktoact_cache, cleaning_token_flood, s_components, trace_occurrences, consider_activities_not_in_model_in_fitness)
#     735                 if activity not in marking_to_activity_caching.cache[start_marking_hash]:
#     736                     marking_to_activity_caching.cache[start_marking_hash][activity] = {
#     737                         "start_marking": start_marking_object, "end_marking": end_marking_object,
#     738                         "this_activated_transitions": this_activated_trans,
#     739                         "this_visited_markings": this_visited_markings,
#     740                         "previousActivity": previous_activity}
#     742 return [is_fit, trace_fitness, act_trans, transitions_with_problems, marking_before_cleaning,
# --> 743         align_utils.get_visible_transitions_eventually_enabled_by_marking(net, marking_before_cleaning), missing,
#     744         consumed,
#     745         remaining, produced]
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\objects\petri_net\utils\align_utils.py:457, in get_visible_transitions_eventually_enabled_by_marking(net, marking)
#     455                     all_enabled_transitions.append(t2)
#     456                     all_enabled_transitions_marking_dictio[t2] = new_marking
# --> 457         visited_transitions.add(repr([t, marking_copy]))
#     458     i = i + 1
#     460 return visible_transitions
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\objects\petri_net\obj.py:65, in Marking.__repr__(self)
#      64 def __repr__(self):
# ---> 65     return str([str(p.name) + ":" + str(self.get(p)) for p in sorted(list(self.keys()), key=lambda x: x.name)])
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\objects\petri_net\obj.py:65, in <listcomp>(.0)
#      64 def __repr__(self):
# ---> 65     return str([str(p.name) + ":" + str(self.get(p)) for p in sorted(list(self.keys()), key=lambda x: x.name)])
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\objects\petri_net\obj.py:94, in PetriNet.Place.__get_name(self)
#      93 def __get_name(self):
# ---> 94     return self.__name
#
# KeyboardInterrupt:

# %% [markdown]
# # Alignments

# %%
pm4py.conformance_diagnostics_alignments(log, net, im, fm)
# Out:
# aligning log, completed variants ::   0%|          | 0/4228 [00:00<?, ?it/s]
# [{'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Transfer Failed (E.Sys.)', '>>'),
#    ('>>', None)],
#   'cost': 100010,
#   'visited_states': 39,
#   'queued_states': 86,
#   'traversed_arcs': 98,
#   'lp_solved': 32,
#   'fitness': 0.4117647058823529,
#   'bwc': 170003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Record Goods Receipt', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Cancel Goods Receipt', '>>'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Transfer Failed (E.Sys.)', '>>'),
#    ('>>', None)],
#   'cost': 120009,
#   'visited_states': 40,
#   'queued_states': 94,
#   'traversed_arcs': 105,
#   'lp_solved': 28,
#   'fitness': 0.4,
#   'bwc': 200003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', 'Delete Purchase Order Item'),
#    ('>>', None)],
#   'cost': 80003,
#   'visited_states': 12,
#   'queued_states': 26,
#   'traversed_arcs': 26,
#   'lp_solved': 2,
#   'fitness': 0.19999999999999996,
#   'bwc': 100003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('Change Delivery Indicator', '>>'),
#    ('>>', None)],
#   'cost': 100010,
#   'visited_states': 39,
#   'queued_states': 87,
#   'traversed_arcs': 98,
#   'lp_solved': 30,
#   'fitness': 0.4117647058823529,
#   'bwc': 170003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 80010,
#   'visited_states': 37,
#   'queued_states': 80,
#   'traversed_arcs': 94,
#   'lp_solved': 28,
#   'fitness': 0.4666666666666667,
#   'bwc': 150003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('>>', None),
#    ('>>', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 90009,
#   'visited_states': 30,
#   'queued_states': 69,
#   'traversed_arcs': 83,
#   'lp_solved': 16,
#   'fitness': 0.4,
#   'bwc': 150003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('>>', None),
#    ('Change Price', 'Change Price'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Change Price', '>>'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Transfer Failed (E.Sys.)', '>>'),
#    ('>>', None)],
#   'cost': 320009,
#   'visited_states': 75,
#   'queued_states': 184,
#   'traversed_arcs': 205,
#   'lp_solved': 68,
#   'fitness': 0.19999999999999996,
#   'bwc': 400003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Transfer Failed (E.Sys.)', '>>'),
#    ('>>', None)],
#   'cost': 100010,
#   'visited_states': 39,
#   'queued_states': 85,
#   'traversed_arcs': 98,
#   'lp_solved': 28,
#   'fitness': 0.4117647058823529,
#   'bwc': 170003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 70009,
#   'visited_states': 22,
#   'queued_states': 57,
#   'traversed_arcs': 57,
#   'lp_solved': 3,
#   'fitness': 0.5333333333333333,
#   'bwc': 150003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('>>', None),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Transfer Failed (E.Sys.)', '>>'),
#    ('>>', None)],
#   'cost': 290009,
#   'visited_states': 44,
#   'queued_states': 111,
#   'traversed_arcs': 111,
#   'lp_solved': 20,
#   'fitness': 0.21621621621621623,
#   'bwc': 370003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates debit memo', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Cancel Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('>>', None),
#    ('Change Price', 'Change Price'),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Clear Invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('Clear Invoice', '>>'),
#    ('Remove Payment Block', 'Remove Payment Block'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Transfer Failed (E.Sys.)', '>>'),
#    ('>>', None)],
#   'cost': 950007,
#   'visited_states': 142,
#   'queued_states': 346,
#   'traversed_arcs': 353,
#   'lp_solved': 70,
#   'fitness': 0.09523809523809523,
#   'bwc': 1050003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Vendor creates invoice', '>>'),
#    ('>>', None),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates debit memo', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Change Price', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Change Price', 'Change Price'),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Cancel Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Change Price', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Remove Payment Block', 'Remove Payment Block'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 2420007,
#   'visited_states': 350,
#   'queued_states': 968,
#   'traversed_arcs': 970,
#   'lp_solved': 355,
#   'fitness': 0.03968253968253965,
#   'bwc': 2520003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('>>', None),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates debit memo', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Change Price', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('SRM: Created', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Change Price', 'Change Price'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('>>', None),
#    ('Record Goods Receipt', '>>'),
#    ('>>', None),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Cancel Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Transfer Failed (E.Sys.)', '>>'),
#    ('>>', None)],
#   'cost': 1130008,
#   'visited_states': 159,
#   'queued_states': 417,
#   'traversed_arcs': 438,
#   'lp_solved': 45,
#   'fitness': 0.07377049180327866,
#   'bwc': 1220003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates debit memo', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Cancel Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('>>', None),
#    ('Change Price', 'Change Price'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('>>', None),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 1730008,
#   'visited_states': 230,
#   'queued_states': 568,
#   'traversed_arcs': 598,
#   'lp_solved': 118,
#   'fitness': 0.0494505494505495,
#   'bwc': 1820003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('>>', None),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Change Price', 'Change Price'),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Cancel Goods Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', '>>'),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Transfer Failed (E.Sys.)', '>>'),
#    ('>>', None)],
#   'cost': 980008,
#   'visited_states': 118,
#   'queued_states': 294,
#   'traversed_arcs': 298,
#   'lp_solved': 45,
#   'fitness': 0.08411214953271029,
#   'bwc': 1070003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('>>', None),
#    ('Vendor creates invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Change Price', 'Change Price'),
#    ('>>', None),
#    ('>>', None),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('>>', None),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Change Price', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Transfer Failed (E.Sys.)', '>>'),
#    ('>>', None)],
#   'cost': 740008,
#   'visited_states': 101,
#   'queued_states': 278,
#   'traversed_arcs': 286,
#   'lp_solved': 47,
#   'fitness': 0.10843373493975905,
#   'bwc': 830003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('>>', None),
#    ('Change Price', 'Change Price'),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', '>>'),
#    ('Record Service Entry Sheet', 'Record Service Entry Sheet'),
#    ('>>', None),
#    ('Record Goods Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('Vendor creates invoice', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 540008,
#   'visited_states': 72,
#   'queued_states': 203,
#   'traversed_arcs': 206,
#   'lp_solved': 48,
#   'fitness': 0.1428571428571429,
#   'bwc': 630003},
#  {'alignment': [('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('SRM: Change was Transmitted', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('SRM: Created', '>>'),
#    ('SRM: Complete', '>>'),
#    ('SRM: Awaiting Approval', '>>'),
#    ('SRM: Document Completed', '>>'),
#    ('SRM: In Transfer to Execution Syst.', '>>'),
#    ('SRM: Ordered', '>>'),
#    ('SRM: Deleted', '>>'),
#    ('Change Price', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Vendor creates invoice', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
#    ('Record Goods Receipt', '>>'),
#    ('Record Service Entry Sheet', '>>'),
#    ('Record Invoice Receipt', '>>'),
#    ('Clear Invoice', '>>'),
# ...
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10,
#   'visited_states': 15,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 1,
#   'fitness': 1.0,
#   'bwc': 70003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Cancel Goods Receipt', '>>'),
#    ('>>', 'Delete Purchase Order Item'),
#    ('Cancel Invoice Receipt', '>>'),
#    ('>>', None)],
#   'cost': 30003,
#   'visited_states': 7,
#   'queued_states': 17,
#   'traversed_arcs': 17,
#   'lp_solved': 4,
#   'fitness': 0.4,
#   'bwc': 50003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Delete Purchase Order Item', 'Delete Purchase Order Item'),
#    ('>>', None)],
#   'cost': 3,
#   'visited_states': 5,
#   'queued_states': 13,
#   'traversed_arcs': 13,
#   'lp_solved': 1,
#   'fitness': 1.0,
#   'bwc': 40003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10,
#   'visited_states': 15,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 1,
#   'fitness': 1.0,
#   'bwc': 70003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Change Quantity', '>>'),
#    ('Change Delivery Indicator', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 30010,
#   'visited_states': 21,
#   'queued_states': 59,
#   'traversed_arcs': 61,
#   'lp_solved': 26,
#   'fitness': 0.7,
#   'bwc': 100003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 49,
#   'traversed_arcs': 49,
#   'lp_solved': 6,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Change Quantity', '>>'),
#    ('Change Delivery Indicator', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 30010,
#   'visited_states': 21,
#   'queued_states': 59,
#   'traversed_arcs': 61,
#   'lp_solved': 26,
#   'fitness': 0.7,
#   'bwc': 100003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 49,
#   'traversed_arcs': 49,
#   'lp_solved': 6,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 49,
#   'traversed_arcs': 49,
#   'lp_solved': 6,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 49,
#   'traversed_arcs': 49,
#   'lp_solved': 6,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Change Quantity', '>>'),
#    ('Change Delivery Indicator', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 30010,
#   'visited_states': 21,
#   'queued_states': 59,
#   'traversed_arcs': 61,
#   'lp_solved': 26,
#   'fitness': 0.7,
#   'bwc': 100003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Change Quantity', '>>'),
#    ('Change Delivery Indicator', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 30010,
#   'visited_states': 21,
#   'queued_states': 59,
#   'traversed_arcs': 61,
#   'lp_solved': 26,
#   'fitness': 0.7,
#   'bwc': 100003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Change Quantity', '>>'),
#    ('Change Delivery Indicator', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 30010,
#   'visited_states': 21,
#   'queued_states': 59,
#   'traversed_arcs': 61,
#   'lp_solved': 26,
#   'fitness': 0.7,
#   'bwc': 100003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Change Quantity', '>>'),
#    ('Change Delivery Indicator', '>>'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 30010,
#   'visited_states': 21,
#   'queued_states': 59,
#   'traversed_arcs': 61,
#   'lp_solved': 26,
#   'fitness': 0.7,
#   'bwc': 100003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  {'alignment': [('>>', None),
#    ('>>', None),
#    ('Create Purchase Order Item', 'Create Purchase Order Item'),
#    ('Change Quantity', '>>'),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('>>', None),
#    ('Vendor creates invoice', 'Vendor creates invoice'),
#    ('Record Goods Receipt', 'Record Goods Receipt'),
#    ('Record Invoice Receipt', 'Record Invoice Receipt'),
#    ('>>', None),
#    ('Clear Invoice', 'Clear Invoice'),
#    ('>>', None)],
#   'cost': 10010,
#   'visited_states': 16,
#   'queued_states': 46,
#   'traversed_arcs': 46,
#   'lp_solved': 7,
#   'fitness': 0.875,
#   'bwc': 80003},
#  ...]

# %%
tree = pm4py.convert_to_process_tree(net, im, fm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 tree = pm4py.convert_to_process_tree(net, im, fm)
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\convert.py:195, in convert_to_process_tree(*args)
#     192     net, im, fm = convert_to_petri_net(*args)
#     194 from pm4py.objects.conversion.wf_net.variants import to_process_tree
# --> 195 tree = to_process_tree.apply(net, im, fm)
#     196 if tree is not None:
#     197     return tree
#
# File ~\anaconda3\envs\process-mining\lib\site-packages\pm4py\objects\conversion\wf_net\variants\to_process_tree.py:312, in apply(net, im, fm, parameters)
#     310     from pm4py.visualization.petri_net import visualizer as pn_viz
#     311     pn_viz.view(pn_viz.apply(grouped_net, parameters={"format": "svg"}))
# --> 312 raise ValueError('Parsing of WF-net Failed')
#
# ValueError: Parsing of WF-net Failed

# %%
from pm4py.algo.discovery.footprints import algorithm as fp_discovery
fp_log = fp_discovery.apply(log, variant=fp_discovery.Variants.ENTIRE_EVENT_LOG)
fp_trace_trace = fp_discovery.apply(log, variant=fp_discovery.Variants.TRACE_BY_TRACE)
fp_tree = fp_discovery.apply(tree, variant=fp_discovery.Variants.PROCESS_TREE)

# %%
tree = pm4py.convert_to_process_tree(net, im, fm)

# %%
from pm4py.algo.conformance.footprints.util import evaluation

fitness = evaluation.fp_fitness(fp_log, fp_tree, conf_result)
precision = evaluation.fp_precision(fp_log, fp_tree)
