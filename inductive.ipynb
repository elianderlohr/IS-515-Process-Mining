# %%
import os
import pm4py

if __name__ == "__main__":
    log = pm4py.read_xes(os.path.join("data", "BPI-min-1-standard-po.xes.gz"))
    net, initial_marking, final_marking = pm4py.discover_petri_net_inductive(log)
# Out:
# parsing log, completed traces ::   0%|          | 0/10934 [00:00<?, ?it/s]

# %%
import os
import pm4py
import pandas as pd

#if __name__ == "__main__":
#    dataframe = pd.read_csv(os.path.join("data", "BPI_Challenge_2019-3-CASE.csv"))
#    dataframe = pm4py.format_dataframe(dataframe, case_id='Case ID', activity_key='Activity', timestamp_key='Complete Timestamp')
#    log = pm4py.convert_to_event_log(dataframe)
#    net, initial_marking, final_marking = pm4py.discover_petri_net_inductive(log)

# %%
tree = pm4py.discover_process_tree_inductive(log)

pm4py.view_process_tree(tree)

# %%
net, initial_marking, final_marking = pm4py.convert_to_petri_net(tree)

# %%
pm4py.view_petri_net(net, initial_marking, final_marking)
